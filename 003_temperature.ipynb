# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()


client = Anthropic()
model = "claude-sonnet-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)
    return messages


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)
    return messages


def chat(messages, system=None, temperature=0.1):

    # Temperature is deprecated in the latest version of the API, but it is still supported for backward compatibility.

    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        # "temperature": temperature,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return "".join(block.text for block in message.content if block.type == "text")

# %%
messages = []

add_user_message(messages, "Generate a one sentence movie idea")

answer = chat(messages)

answer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       1 messages = []
#       2
#       3 add_user_message(messages, "Generate a one sentence movie idea")
#       4
# ----> 5 answer = chat(messages)
#       6
#       7 answer
#
# Cell In[8], line 28, in chat(messages, system, temperature)
#      24
#      25     if system:
#      26         params["system"] = system
#      27
# ---> 28     message = client.messages.create(**params)
#      29     return "".join(block.text for block in message.content if block.type == "text")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# TypeError: Messages.create() got an unexpected keyword argument 'creativity'
